# %%
import pickle
import pandas as pd
import numpy as np

# %%
def load_data_from_pickle(obj_name):
    '''
    load_data_from_pickle function loads and deserializes an object from a pickle file.

    Args:
        obj_name (str): The path to the pickle file containing the serialized object. 

    Returns:
        obj (pd.DataFrame): The deserialized object that was stored in the pickle file. 

    '''
    with open(obj_name, 'rb') as file:
        obj = pickle.load(file)
    return obj

# %%
X_train = load_data_from_pickle("/Users/rishabkhuba/Documents/MLOps_Project/IE7374-Sepsis-Classification/data/data_processed_data_X_train.pkl")
y_train = load_data_from_pickle("/Users/rishabkhuba/Documents/MLOps_Project/IE7374-Sepsis-Classification/data/data_processed_data_y_train.pkl")

# %%
X_train.head()
# Out:
#          HR     O2Sat      Temp       MAP      Resp       BUN  Chloride  \
# 0  0.698995 -0.715588 -1.109735 -0.174409  0.037447 -0.415783 -3.709458
# 1  0.698995 -0.715588 -1.109735 -0.174409  0.037447 -0.415783 -3.709458
# 2  0.230384  0.567707 -1.109735  0.532922  0.590630 -0.415783 -3.709458
# 3  0.288960 -0.715588 -1.109735  0.854368  2.065783 -0.415783 -3.709458
# 4  1.050454 -2.800943 -1.109735  0.854368  1.051615 -0.415783 -3.709458
#
#    Creatinine   Glucose       Hct       Hgb     WBC  Platelets    Age  \
# 0   -0.562354  1.427761  1.228097  1.115818 -1.2792   1.053533  83.14
# 1   -0.562354  1.427761  1.228097  1.115818 -1.2792   1.053533  83.14
# 2   -0.562354  1.427761  1.228097  1.115818 -1.2792   1.053533  83.14
# 3   -0.562354  1.427761  1.228097  1.115818 -1.2792   1.053533  83.14
# 4   -0.562354  1.427761  1.228097  1.115818 -1.2792   1.053533  83.14
#
#    HospAdmTime  ICULOS     0      1
# 0        -0.03       1  True  False
# 1        -0.03       2  True  False
# ...

# %%
X_train.columns
# Out:
# Index([         'HR',       'O2Sat',        'Temp',         'MAP',
#               'Resp',         'BUN',    'Chloride',  'Creatinine',
#            'Glucose',         'Hct',         'Hgb',         'WBC',
#          'Platelets',         'Age', 'HospAdmTime',      'ICULOS',
#                    0,             1],
#       dtype='object')

# %%
y_train.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
X_train.shape
# Out:
# (584213, 18)

# %%
y_train.shape
# Out:
# (584213,)

# %%
y_train.value_counts()
# Out:
# SepsisLabel
# 0    572528
# 1     11685
# Name: count, dtype: int64

# %%
X_test = load_data_from_pickle("/Users/rishabkhuba/Documents/MLOps_Project/IE7374-Sepsis-Classification/data/data_processed_data_X_test.pkl")
y_test = load_data_from_pickle("/Users/rishabkhuba/Documents/MLOps_Project/IE7374-Sepsis-Classification/data/data_processed_data_y_test.pkl")

# %%
X_test.head(50)
# Out:
#           HR     O2Sat      Temp       MAP      Resp       BUN  Chloride  \
# 0   1.401913  0.888531 -0.503610  0.532922 -0.054750 -1.052105  1.044956
# 1   1.519066  0.888531 -0.288099  0.795498  4.462908 -1.052105  1.044956
# 2   1.284760  0.567707 -0.355446  0.011458  1.328206 -1.052105  1.044956
# 3   1.226183  0.567707 -0.355446 -0.342000  1.328206 -1.052105  1.044956
# 4   1.050454 -0.073941 -0.355446  0.011458  1.328206 -1.052105  1.044956
# 5   0.874725  0.567707 -0.355446  0.491129  1.328206 -1.052105  1.044956
# 6   0.640419  0.246883 -0.288099 -0.150383  1.328206 -1.052105  1.044956
# 7   0.581843  0.246883 -0.288099  1.065088  1.328206 -1.052105  1.044956
# 8   0.523266  0.567707 -0.288099  1.339563  1.328206 -1.052105  1.044956
# 9   0.581843  0.246883 -0.288099  0.716194  1.328206 -1.052105  1.044956
# 10  0.406113  0.888531 -0.813407  0.146615  1.328206 -1.052105  1.044956
# 11  0.113231  0.567707 -0.813407  0.146615  1.328206 -1.052105  1.044956
# ...

# %%
X_test.tail()
# Out:
#               HR     O2Sat      Temp       MAP      Resp       BUN  Chloride  \
# 231767  0.933301  0.567707  0.089045  1.392825 -0.515736 -1.611857  1.044956
# 231768  0.933301  0.567707  0.089045  1.392825 -0.515736 -1.611857  1.044956
# 231769  0.933301  0.567707  0.089045  1.392825 -0.515736 -1.611857  1.044956
# 231770  0.933301  0.567707  0.089045  1.392825 -0.515736 -1.611857  1.044956
# 231771  0.933301  0.567707  0.089045  1.392825 -0.515736 -1.611857  1.044956
#
#         Creatinine   Glucose       Hct       Hgb       WBC  Platelets   Age  \
# 231767   -0.640761 -0.055575 -0.652853 -0.756578 -0.534876  -0.600858  35.0
# 231768   -0.640761 -0.055575 -0.652853 -0.756578 -0.534876  -0.600858  35.0
# 231769   -0.640761 -0.055575 -0.652853 -0.756578 -0.534876  -0.600858  35.0
# 231770   -0.640761 -0.055575 -0.652853 -0.756578 -0.534876  -0.600858  35.0
# 231771   -0.640761 -0.055575 -0.652853 -0.756578 -0.534876  -0.600858  35.0
#
#         HospAdmTime  ICULOS      0     1
# ...

# %%
y_test.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
y_test.value_counts()
# Out:
# SepsisLabel
# 0    191068
# 1      3972
# Name: count, dtype: int64

# %%
11685 /(11685 + 572528)
# Out:
# 0.020001266661303325

# %%
# Path to your CSV file
file_path = '/Users/sharanyasenthil/Downloads/data_modified_data_finalDataset-000000000000.csv'

# Load the first 1000 rows of the CSV file
df = pd.read_csv(file_path, nrows=1000)

# print(df.head())

# %%
X = df.drop(columns="SepsisLabel", axis=1)
y = df["SepsisLabel"]

# %%
X.head(10)
# Out:
#      HR  O2Sat   Temp    SBP    MAP   DBP  Resp  EtCO2  BaseExcess  HCO3  ...  \
# 0   NaN    NaN    NaN    NaN    NaN   NaN   NaN    NaN         NaN   NaN  ...
# 1  61.0   99.0  36.44  124.0   65.0  43.0  17.5    NaN         NaN   NaN  ...
# 2  64.0   98.0    NaN  125.0   64.0  41.0  27.0    NaN         NaN   NaN  ...
# 3  56.0  100.0    NaN  123.0   65.0  41.0   9.0    NaN         NaN   NaN  ...
# 4  66.0   99.0    NaN  120.0   67.0  43.0  23.0    NaN         NaN   NaN  ...
# 5  94.0  100.0  36.22  194.0  116.0  66.0  14.0    NaN         NaN   NaN  ...
# 6  58.0   99.0    NaN  133.0   68.0  43.0  13.0    NaN         NaN   NaN  ...
# 7  57.0  100.0    NaN  118.0   62.0  37.0  18.0    NaN         NaN   NaN  ...
# 8  62.0  100.0    NaN  126.0   66.0  37.0  12.0    NaN         NaN   NaN  ...
# 9  58.0   95.0  36.11  143.0   77.0  47.0  11.0    NaN         NaN  22.0  ...
#
#     WBC  Fibrinogen  Platelets    Age  Gender  Unit1  Unit2  HospAdmTime  \
# ...

# %%
X.columns
# Out:
# Index(['HR', 'O2Sat', 'Temp', 'SBP', 'MAP', 'DBP', 'Resp', 'EtCO2',
#        'BaseExcess', 'HCO3', 'FiO2', 'pH', 'PaCO2', 'SaO2', 'AST', 'BUN',
#        'Alkalinephos', 'Calcium', 'Chloride', 'Creatinine', 'Bilirubin_direct',
#        'Glucose', 'Lactate', 'Magnesium', 'Phosphate', 'Potassium',
#        'Bilirubin_total', 'TroponinI', 'Hct', 'Hgb', 'PTT', 'WBC',
#        'Fibrinogen', 'Platelets', 'Age', 'Gender', 'Unit1', 'Unit2',
#        'HospAdmTime', 'ICULOS', 'Patient_ID'],
#       dtype='object')

# %%
import numpy as np

def data_preprocess_pipeline(features, target):

    """
    Load, preprocess, and save the dataframe.

    Args:
        data_input (str): Path to the input pickle file containing the independent features in the dataframe.
        target_input (str): Path to the input pickle file containing the target values in the datframe.
    Return:
        Dataframe (pd.DataFrame): preprocessed dataframe containing features is returned  
    """

    if True:
        # print(features.head())
        # print(target.head())
        # Load data from pickle file
        X = features
        y = target

        # print(f"Shape of X before preprocessing: {X.shape}")
        # print(f"Shape of y before preprocessing: {y.shape}")

        # Preprocess the dataframe
        columns_to_drop = ['SBP', 'DBP', 'EtCO2', 'BaseExcess', 'HCO3',
                           'pH', 'PaCO2', 'Alkalinephos', 'Calcium',
                           'Magnesium', 'Phosphate', 'Potassium', 'PTT',
                           'Fibrinogen', 'Unit1', 'Unit2']
        X["Unit"] = X["Unit1"] + X["Unit2"]

        # Drop redundant columns
        X.drop(columns=columns_to_drop, inplace=True)

        # Join X and y
        df = pd.concat([X, y], axis=1)

        grouped_by_patient = df.groupby('Patient_ID')

        # Impute missing values with forward and backward fill
        df = grouped_by_patient.apply(lambda x: x.bfill().ffill()).reset_index(drop=True)

        # Drop columns with more than 25% null values and 'Patient_ID'
        columns_with_""""""""null""""""""s = ['TroponinI', 'Bilirubin_direct', 'AST', 'Bilirubin_total',
                              'Lactate', 'SaO2', 'FiO2', 'Unit', 'Patient_ID']
        df.drop(columns=columns_with_nulls, inplace=True)

        # Apply log transformation to normalize specific columns
        columns_to_normalize = ['MAP', 'BUN', 'Creatinine', 'Glucose', 'WBC', 'Platelets']
        for col in columns_to_normalize:
            df[col] = np.log1p(df[col])


        # One-hot encode the 'Gender' column
        
        df['gender'] = df['Gender'].replace({1: 'M', 0: 'F'}).apply(lambda x: x if x in ['M', 'F'] else np.nan)
        
        
        encoded_gender_col = pd.get_dummies(df["gender"])
        
        df = df.join(encoded_gender_col)
        df = df.drop(columns = ["Gender", "gender"], axis=1)

        df['F'] = df['F'].astype(int)
        df['M'] = df['M'].astype(int)

        # Drop remaining rows with any NaN values
        df.dropna(inplace=True)

        # Split the dataframe back into X and y
        X_preprocessed = df.drop(columns=['SepsisLabel']).reset_index(drop=True)
        y_preprocessed = df['SepsisLabel']
        
        X_preprocessed = X_preprocessed.drop(columns=X_preprocessed.columns[X_preprocessed.columns.str.contains('^Unnamed', case=False, regex=True)])

        return X_preprocessed, y_preprocessed
        
    # except KeyError as ke:
    #     print("KeyError during preprocessing: %s", ke)
    # except ValueError as ve:
    #     print("ValueError during preprocessing: %s", ve)
    # except Exception as ex:
    #     print("An unexpected error occurred during preprocessing: %s", ex)
    #     raise

# %%
X_preprocessed, y_preprocessed = data_preprocess_pipeline(X, y)

# %%
X.shape, X_preprocessed.shape
# Out:
# ((1000, 26), (959, 18))

# %%
del X_preprocessed, y_preprocessed

# %%
X_preprocessed.columns
# Out:
# Index(['HR', 'O2Sat', 'Temp', 'MAP', 'Resp', 'BUN', 'Chloride', 'Creatinine',
#        'Glucose', 'Hct', 'Hgb', 'WBC', 'Platelets', 'Age', 'HospAdmTime',
#        'ICULOS', 'F', 'M'],
#       dtype='object')

# %%
X_preprocessed.shape
# Out:
# (959, 18)

# %%
def check_collinearity(df, col1, col2):
    """
    Check collinearity between two columns in a DataFrame.

    Args:
        df (pd.DataFrame): The DataFrame containing the columns.
        col1 (str): The name of the first column.
        col2 (str): The name of the second column.

    Returns:
        float: The Pearson correlation coefficient between the two columns.
    """
    correlation = df[[col1, col2]].corr().iloc[0, 1]
    print(f"Correlation between {col1} and {col2}: {correlation}")
    return correlation

# %%
check_collinearity(X_preprocessed, "Unnamed: 0", "Hour")
# Out:
# Correlation between Unnamed: 0 and Hour: 1.0
# 1.0

# %%
# Identify columns that contain the pattern '^Unnamed'
unnamed_columns = X_preprocessed.columns.str.contains('^Unnamed', case=False, regex=True)

# Get the names of these columns
columns_to_drop = X_preprocessed.columns[unnamed_columns]

# Drop the identified columns
X_preprocessed_filtered = X_preprocessed.drop(columns=columns_to_drop)

print("Columns to drop:", columns_to_drop)
print("Filtered DataFrame:")
print(X_preprocessed_filtered)
# Out:
# Columns to drop: Index(['Unnamed: 0'], dtype='object')
# Filtered DataFrame:
#      Hour    HR  O2Sat   Temp       MAP  Resp       BUN  Chloride  Creatinine  \
# 0       0  58.0   97.0  36.44  3.988984  15.0  3.332205     100.0    0.587787
# 1       1  58.0   97.0  36.44  3.988984  15.0  3.332205     100.0    0.587787
# 2       2  59.0   96.0  36.44  4.143135  23.0  3.332205     100.0    0.587787
# 3       3  56.0   95.0  36.44  4.164026  21.0  3.332205     100.0    0.587787
# 4       4  70.0   98.0  36.44  4.204693  16.0  3.332205     100.0    0.587787
# ..    ...   ...    ...    ...       ...   ...       ...       ...         ...
# 871    20  56.0   98.5  37.20  4.110874  14.5  3.044522     108.0    0.587787
# 872    21  52.0   99.0  37.22  4.234107  15.0  3.044522     108.0    0.587787
# 873    22  52.0   99.0  37.22  4.330733  14.0  3.044522     108.0    0.587787
# 874    23  54.0   97.5  37.22  4.212128  15.5  3.044522     108.0    0.587787
# ...

# %%
X.iloc[:100,:].to_clipboard(sep=',')

# %%
X.iloc[:100, :].fillna('null').to_clipboard(sep=',', index = False)

# %%
! pip install pyperclip
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11125 sha256=a3ac58c24094d678982331f74c2a87151ceed4b749937e9e7a0841fcc519c815
#   Stored in directory: /Users/sharanyasenthil/Library/Caches/pip/wheels/70/bd/ba/8ae5c080c895c9360fe6e153acda2dee82527374467eae061b
# Successfully built pyperclip
# ...

# %%
import json
import pyperclip  # Ensure you have the pyperclip module installed (pip install pyperclip)

X_subset = X.iloc[:100, :]

# Convert NaN to None
X_subset = X_subset.replace({np.nan: None})

# Convert the DataFrame to a list of lists
data_list = X_subset.values.tolist()

# Create a custom JSON encoder to handle None and strings properly
class CustomJSONEncoder(json.JSONEncoder):
    def default(self, obj):
        if obj is None:
            return obj
        return super(CustomJSONEncoder, self).default(obj)

# Convert the list of lists to a JSON string
json_str = json.dumps(data_list, cls=CustomJSONEncoder)

# Copy the JSON string to the clipboard
pyperclip.copy(json_str)

print("JSON string copied to clipboard.")
# Out:
# JSON string copied to clipboard.

# %%
[[null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 75.91, 0, 0.0, 1.0, -98.6, 1, "p000002"], [61.0, 99.0, 36.44, 124.0, 65.0, 43.0, 17.5, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 75.91, 0, 0.0, 1.0, -98.6, 2, "p000002"], [64.0, 98.0, null, 125.0, 64.0, 41.0, 27.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 75.91, 0, 0.0, 1.0, -98.6, 3, "p000002"], [56.0, 100.0, null, 123.0, 65.0, 41.0, 9.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 75.91, 0, 0.0, 1.0, -98.6, 4, "p000002"], [66.0, 99.0, null, 120.0, 67.0, 43.0, 23.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 75.91, 0, 0.0, 1.0, -98.6,
, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 1, "p000004"], [103.5, 97.0, null, 107.5, 70.5, 52.0, 18.0, null, null, 22.0, null, null, null, null, null, 14.0, null, null, 105.0, 0.8, null, null, null, 1.7, null, null, null, null, 27.6, null, 21.3, null, null, 220.0, 65.71, 0, 0.0, 1.0, -8.77, 2, "p000004"], [108.0, 98.5, 36.78, 124.5, 82.0, 61.5, 19.5, null, 0.0, null, null, 7.36, 45.0, 98.0, null, null, null, null, null, null, null, 253.0, null, null, null, 5.0, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 3, "p000004"], [107.5, 96.5, null, 117.5, 77.5, 58.5, 17.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 4, "p000004"], [113.0, 100.0, null, 125.0, 80.0, 61.0, 26.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 5, "p000004"], [107.0, 100.0, null, 116.0, 72.0, 52.0, 26.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 6, "p000004"], [93.0, 100.0, 36.06, 132.5, 84.0, 58.5, 15.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 7, "p000004"], [94.0, 100.0, null, 90.0, 34.0, 44.0, 14.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 8, "p000004"], [95.0, 98.0, null, 115.0, 72.0, 48.0, 25.0, null, 0.0, null, null, 7.4, 41.0, 97.5, null, null, null, null, null, null, null, 84.0, null, null, null, 4.0, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 9, "p000004"], [95.0, 95.5, null, 111.5, 69.5, 47.0, 18.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 10, "p000004"], [94.0, 98.0, null, 117.0, 72.0, 47.0, 17.0, null, null, 22.0, null, 7.41, null, 98.0, null, 19.0, null, 8.2, 108.0, 0.8, null, 69.0, null, 2.4, 3.8, 4.3, null, null, 24.0, 8.3, 22.3, 7.6, null, 144.0, 65.71, 0, 0.0, 1.0, -8.77, 11, "p000004"], [94.0, 99.0, 36.39, 108.0, 66.0, 45.0, 21.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 12, "p000004"], [95.0, 97.0, null, 115.0, 68.0, 45.0, 18.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 13, "p000004"], [94.0, 100.0, null, 108.0, 70.0, 49.0, 15.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 14, "p000004"], [97.0, 96.0, null, 117.0, 73.0, 51.5, 15.5, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 15, "p000004"], [100.0, 98.0, null, 112.0, 56.67, null, 16.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 16, "p000004"], [106.0, 96.0, null, 107.0, 60.33, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 17, "p000004"], [106.0, 100.0, 36.39, 103.0, 52.33, null, 18.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 18, "p000004"], [102.0, 98.0, null, null, null, null, 24.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 19, "p000004"], [101.0, 99.0, null, 98.0, 58.0, null, 22.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 20, "p000004"], [105.0, 98.0, null, 108.0, 70.0, null, 16.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 21, "p000004"], [105.0, 96.0, null, 104.0, 63.33, null, 22.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 22, "p000004"], [106.0, 100.0, 36.39, 111.0, 65.0, null, 21.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 65.71, 0, 0.0, 1.0, -8.77, 23, "p000004"]]
# Out:
#        HR  O2Sat   Temp    SBP   MAP   DBP  Resp  EtCO2  BaseExcess  HCO3  \
# 0     NaN    NaN    NaN    NaN   NaN   NaN   NaN    NaN         NaN   NaN
# 1    61.0   99.0  36.44  124.0  65.0  43.0  17.5    NaN         NaN   NaN
# 2    64.0   98.0    NaN  125.0  64.0  41.0  27.0    NaN         NaN   NaN
# 3    56.0  100.0    NaN  123.0  65.0  41.0   9.0    NaN         NaN   NaN
# 4    66.0   99.0    NaN  120.0  67.0  43.0  23.0    NaN         NaN   NaN
# ..    ...    ...    ...    ...   ...   ...   ...    ...         ...   ...
# 995  83.0  100.0    NaN  129.0  76.0  50.0  17.0    NaN         NaN   NaN
# 996  80.0   99.0    NaN   89.0  57.0  41.0  18.0    NaN         NaN   NaN
# 997  79.5  100.0    NaN  143.0  84.0  52.5  19.0    NaN        -3.0   NaN
# 998  85.0  100.0    NaN  161.0  92.0  56.0  18.0    NaN        -3.0   NaN
# 999  69.0   95.0    NaN   91.0  56.0  43.0  15.0    NaN         NaN   NaN
#
#      ...  WBC  Fibrinogen  Platelets    Age  Gender  Unit1  Unit2  \
# ...
